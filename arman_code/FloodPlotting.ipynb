# %%
import geopandas as gpd

# %%
waterbodies_shape = gpd.read_file('cb_2018_us_state_500k.shp')

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(15,15))
waterbodies_shape.plot(ax=ax)
# Out:
# <Axes: >

# %%
# Necessary imports to work with netCDF 3D arrays
import xarray
import rioxarray
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
